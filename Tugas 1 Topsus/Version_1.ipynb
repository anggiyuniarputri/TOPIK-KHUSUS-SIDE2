# %%
import pandas
import os
from nltk import pos_tag, word_tokenize

# %%
data_set = pandas.read_csv(os.getcwd() +'/Dataset Canon S100 Reanotasi.csv', sep='delimiter', header=None)

i = 1
list_pos_tag = []
for data in data_set[0]:
    print(str(i) +' - ' +data)
    text = word_tokenize(data)
    postag = pos_tag(text)
    list_pos_tag.append(postag)
    print(postag)
    print('')
    i += 1
    
raw_data = {'pos_tag': list_pos_tag}
df = pandas.DataFrame(raw_data, columns=['pos_tag'])
df.to_csv(os.getcwd() +'/Version_1.csv', index=False)
# Out:
# /Users/dennymaulana/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# 1 - camera[-3]##i want to start off saying that this camera is small for a reason.
# [('camera', 'NN'), ('[', 'NN'), ('-3', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('i', 'NN'), ('want', 'VBP'), ('to', 'TO'), ('start', 'VB'), ('off', 'RP'), ('saying', 'VBG'), ('that', 'IN'), ('this', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('small', 'JJ'), ('for', 'IN'), ('a', 'DT'), ('reason', 'NN'), ('.', '.')]
#
# 2 - size[-2],camera[+2]##some people, in their reviews, complain about its small size, and how it doesn't compare with larger cameras.
# [('size', 'NN'), ('[', 'NNP'), ('-2', 'NNP'), (']', 'NNP'), (',', ','), ('camera', 'NN'), ('[', 'NN'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('some', 'DT'), ('people', 'NNS'), (',', ','), ('in', 'IN'), ('their', 'PRP$'), ('reviews', 'NNS'), (',', ','), ('complain', 'VBP'), ('about', 'IN'), ('its', 'PRP$'), ('small', 'JJ'), ('size', 'NN'), (',', ','), ('and', 'CC'), ('how', 'WRB'), ('it', 'PRP'), ('does', 'VBZ'), ("n't", 'RB'), ('compare', 'VB'), ('with', 'IN'), ('larger', 'JJR'), ('cameras', 'NNS'), ('.', '.')]
#
# 3 - camera[+3]##i'm in high school, and this camera is perfect for what i use it for, carrying it around in my pocket so i can take pictures whenever i want to, of my friends and of funny things that happen.
# [('camera', 'NN'), ('[', 'NN'), ('+3', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('i', 'JJ'), ("'m", 'VBP'), ('in', 'IN'), ('high', 'JJ'), ('school', 'NN'), (',', ','), ('and', 'CC'), ('this', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('perfect', 'JJ'), ('for', 'IN'), ('what', 'WP'), ('i', 'NN'), ('use', 'VBP'), ('it', 'PRP'), ('for', 'IN'), (',', ','), ('carrying', 'VBG'), ('it', 'PRP'), ('around', 'IN'), ('in', 'IN'), ('my', 'PRP$'), ('pocket', 'NN'), ('so', 'IN'), ('i', 'JJ'), ('can', 'MD'), ('take', 'VB'), ('pictures', 'NNS'), ('whenever', 'WRB'), ('i', 'NN'), ('want', 'VBP'), ('to', 'TO'), (',', ','), ('of', 'IN'), ('my', 'PRP$'), ('friends', 'NNS'), ('and', 'CC'), ('of', 'IN'), ('funny', 'JJ'), ('things', 'NNS'), ('that', 'WDT'), ('happen', 'VBP'), ('.', '.')]
#
# 4 - card[-2]##the only thing i don't like is the small size (8 meg) memory card that comes with it.
# [('card', 'NN'), ('[', 'NNP'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('only', 'JJ'), ('thing', 'NN'), ('i', 'NNS'), ('do', 'VBP'), ("n't", 'RB'), ('like', 'VB'), ('is', 'VBZ'), ('the', 'DT'), ('small', 'JJ'), ('size', 'NN'), ('(', '('), ('8', 'CD'), ('meg', 'NN'), (')', ')'), ('memory', 'NN'), ('card', 'NN'), ('that', 'WDT'), ('comes', 'VBZ'), ('with', 'IN'), ('it', 'PRP'), ('.', '.')]
#
# 5 - ##i have to move pictures off of it every day so i have room for more pictures the next, and i don't have enough money to buy the 256 meg card that i've had my eye on for a while.
# [('#', '#'), ('#', '#'), ('i', 'NNS'), ('have', 'VBP'), ('to', 'TO'), ('move', 'VB'), ('pictures', 'NNS'), ('off', 'IN'), ('of', 'IN'), ('it', 'PRP'), ('every', 'DT'), ('day', 'NN'), ('so', 'IN'), ('i', 'JJ'), ('have', 'VBP'), ('room', 'NN'), ('for', 'IN'), ('more', 'JJR'), ('pictures', 'NNS'), ('the', 'DT'), ('next', 'JJ'), (',', ','), ('and', 'CC'), ('i', 'NNS'), ('do', 'VBP'), ("n't", 'RB'), ('have', 'VB'), ('enough', 'JJ'), ('money', 'NN'), ('to', 'TO'), ('buy', 'VB'), ('the', 'DT'), ('256', 'CD'), ('meg', 'NNS'), ('card', 'VBP'), ('that', 'IN'), ('i', 'NN'), ("'ve", 'VBP'), ('had', 'VBN'), ('my', 'PRP$'), ('eye', 'NN'), ('on', 'IN'), ('for', 'IN'), ('a', 'DT'), ('while', 'NN'), ('.', '.')]
#
# 6 - memory[-1],battery[-1]##a larger memory card and extra battery are good things to buy.
# [('memory', 'NN'), ('[', 'NNP'), ('-1', 'NNP'), (']', 'NNP'), (',', ','), ('battery', 'NN'), ('[', 'NN'), ('-1', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('a', 'DT'), ('larger', 'JJR'), ('memory', 'NN'), ('card', 'NN'), ('and', 'CC'), ('extra', 'JJ'), ('battery', 'NN'), ('are', 'VBP'), ('good', 'JJ'), ('things', 'NNS'), ('to', 'TO'), ('buy', 'VB'), ('.', '.')]
#
# 7 - picture[-2]##other than that pictures taken in the dark are not as nice as i'd like them,
# [('picture', 'NN'), ('[', 'VBZ'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('other', 'JJ'), ('than', 'IN'), ('that', 'DT'), ('pictures', 'VBZ'), ('taken', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('dark', 'NN'), ('are', 'VBP'), ('not', 'RB'), ('as', 'RB'), ('nice', 'JJ'), ('as', 'IN'), ('i', 'JJ'), ("'d", 'MD'), ('like', 'VB'), ('them', 'PRP'), (',', ',')]
#
# 8 - camera[+3]##i'd say that this camera is perfect.
# [('camera', 'NN'), ('[', 'NN'), ('+3', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('i', 'JJ'), ("'d", 'MD'), ('say', 'VB'), ('that', 'IN'), ('this', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('perfect', 'JJ'), ('.', '.')]
#
# 9 - camera[+2]##ok, not quite everything...but this camera is so compact that you will have it by your side when you need it.
# [('camera', 'NN'), ('[', 'NN'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('ok', 'NN'), (',', ','), ('not', 'RB'), ('quite', 'RB'), ('everything', 'NN'), ('...', ':'), ('but', 'CC'), ('this', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('so', 'RB'), ('compact', 'JJ'), ('that', 'IN'), ('you', 'PRP'), ('will', 'MD'), ('have', 'VB'), ('it', 'PRP'), ('by', 'IN'), ('your', 'PRP$'), ('side', 'NN'), ('when', 'WRB'), ('you', 'PRP'), ('need', 'VBP'), ('it', 'PRP'), ('.', '.')]
#
# 10 - size[+2],camera[+2]##i bought this camera for the same reason many of you are considering it, or have already bought it--it's size.
# [('size', 'NN'), ('[', 'NNP'), ('+2', 'NNP'), (']', 'NNP'), (',', ','), ('camera', 'NN'), ('[', 'NN'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('i', 'JJ'), ('bought', 'VBD'), ('this', 'DT'), ('camera', 'NN'), ('for', 'IN'), ('the', 'DT'), ('same', 'JJ'), ('reason', 'NN'), ('many', 'JJ'), ('of', 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('considering', 'VBG'), ('it', 'PRP'), (',', ','), ('or', 'CC'), ('have', 'VBP'), ('already', 'RB'), ('bought', 'VBN'), ('it', 'PRP'), ('--', ':'), ('it', 'PRP'), ("'s", 'VBZ'), ('size', 'NN'), ('.', '.')]
#
# 11 - ##it is amazingly small, it's hard to believe all that has been packed into this camera.
# [('#', '#'), ('#', '#'), ('it', 'PRP'), ('is', 'VBZ'), ('amazingly', 'RB'), ('small', 'JJ'), (',', ','), ('it', 'PRP'), ("'s", 'VBZ'), ('hard', 'JJ'), ('to', 'TO'), ('believe', 'VB'), ('all', 'PDT'), ('that', 'DT'), ('has', 'VBZ'), ('been', 'VBN'), ('packed', 'VBN'), ('into', 'IN'), ('this', 'DT'), ('camera', 'NN'), ('.', '.')]
#
# 12 - ##i take it with me everywhere,literally,
# [('#', '#'), ('#', '#'), ('i', 'NNS'), ('take', 'VBP'), ('it', 'PRP'), ('with', 'IN'), ('me', 'PRP'), ('everywhere', 'RB'), (',', ','), ('literally', 'RB'), (',', ',')]
#
# 13 - ##it is so small that i am able to keep it in my pocket, and i don't have to fear that it will get ruined in my pocket because it is so durable.
# [('#', '#'), ('#', '#'), ('it', 'PRP'), ('is', 'VBZ'), ('so', 'RB'), ('small', 'JJ'), ('that', 'IN'), ('i', 'JJ'), ('am', 'VBP'), ('able', 'JJ'), ('to', 'TO'), ('keep', 'VB'), ('it', 'PRP'), ('in', 'IN'), ('my', 'PRP$'), ('pocket', 'NN'), (',', ','), ('and', 'CC'), ('i', 'NNS'), ('do', 'VBP'), ("n't", 'RB'), ('have', 'VB'), ('to', 'TO'), ('fear', 'VB'), ('that', 'IN'), ('it', 'PRP'), ('will', 'MD'), ('get', 'VB'), ('ruined', 'VBN'), ('in', 'IN'), ('my', 'PRP$'), ('pocket', 'NN'), ('because', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('so', 'RB'), ('durable', 'JJ'), ('.', '.')]
#
# 14 - cover[+2],lens[+2]##there is also a small covering for the lens, so you need not worry that the lens will get scratched.
# [('cover', 'NN'), ('[', 'NNP'), ('+2', 'NNP'), (']', 'NNP'), (',', ','), ('lens', 'VBZ'), ('[', 'NNP'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('there', 'EX'), ('is', 'VBZ'), ('also', 'RB'), ('a', 'DT'), ('small', 'JJ'), ('covering', 'NN'), ('for', 'IN'), ('the', 'DT'), ('lens', 'NNS'), (',', ','), ('so', 'IN'), ('you', 'PRP'), ('need', 'VBP'), ('not', 'RB'), ('worry', 'VB'), ('that', 'IN'), ('the', 'DT'), ('lens', 'NNS'), ('will', 'MD'), ('get', 'VB'), ('scratched', 'VBN'), ('.', '.')]
#
# 15 - picture quality[-2]##the picture quality surprised me, when i first saw this camera i saw how small it was an instantly assumed that the picture quality would not be good--but i was wrong!
# [('picture', 'NN'), ('quality', 'NN'), ('[', 'NNP'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('picture', 'NN'), ('quality', 'NN'), ('surprised', 'VBD'), ('me', 'PRP'), (',', ','), ('when', 'WRB'), ('i', 'NN'), ('first', 'RB'), ('saw', 'VBD'), ('this', 'DT'), ('camera', 'NN'), ('i', 'NN'), ('saw', 'VBD'), ('how', 'WRB'), ('small', 'JJ'), ('it', 'PRP'), ('was', 'VBD'), ('an', 'DT'), ('instantly', 'RB'), ('assumed', 'VBN'), ('that', 'IN'), ('the', 'DT'), ('picture', 'NN'), ('quality', 'NN'), ('would', 'MD'), ('not', 'RB'), ('be', 'VB'), ('good', 'JJ'), ('--', ':'), ('but', 'CC'), ('i', 'NN'), ('was', 'VBD'), ('wrong', 'JJ'), ('!', '.')]
#
# 16 - picture quality[+3],size[+3],price[+3]##the picture quality of this camera is outstanding (taking its' size and price into consideration).
# [('picture', 'NN'), ('quality', 'NN'), ('[', 'NNP'), ('+3', 'NNP'), (']', 'NNP'), (',', ','), ('size', 'NN'), ('[', 'NNP'), ('+3', 'NNP'), (']', 'NNP'), (',', ','), ('price', 'NN'), ('[', 'NNS'), ('+3', 'VBP'), (']', 'JJ'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('picture', 'NN'), ('quality', 'NN'), ('of', 'IN'), ('this', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('outstanding', 'JJ'), ('(', '('), ('taking', 'VBG'), ('its', 'PRP$'), ("'", 'POS'), ('size', 'NN'), ('and', 'CC'), ('price', 'NN'), ('into', 'IN'), ('consideration', 'NN'), (')', ')'), ('.', '.')]
#
# 17 - ##however, i do have a few things to complain about...
# [('#', '#'), ('#', '#'), ('however', 'RB'), (',', ','), ('i', 'NNS'), ('do', 'VBP'), ('have', 'VB'), ('a', 'DT'), ('few', 'JJ'), ('things', 'NNS'), ('to', 'TO'), ('complain', 'VB'), ('about', 'IN'), ('...', ':')]
#
# 18 - ##first off, the battery.
# [('#', '#'), ('#', '#'), ('first', 'RB'), ('off', 'RB'), (',', ','), ('the', 'DT'), ('battery', 'NN'), ('.', '.')]
#
# 19 - "battery[-2]##this camera uses a lithium battery, i find lithium batteries to be highly inconvenient; because what if you are on vacation, where the nearest place to buy batteries is just a gas station--there is no way that you are going to find lithium batteries there."
# [('``', '``'), ('battery', 'NN'), ('[', 'NN'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('this', 'DT'), ('camera', 'NN'), ('uses', 'VBZ'), ('a', 'DT'), ('lithium', 'NN'), ('battery', 'NN'), (',', ','), ('i', 'JJ'), ('find', 'VBP'), ('lithium', 'JJ'), ('batteries', 'NNS'), ('to', 'TO'), ('be', 'VB'), ('highly', 'RB'), ('inconvenient', 'JJ'), (';', ':'), ('because', 'IN'), ('what', 'WP'), ('if', 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('on', 'IN'), ('vacation', 'NN'), (',', ','), ('where', 'WRB'), ('the', 'DT'), ('nearest', 'JJS'), ('place', 'NN'), ('to', 'TO'), ('buy', 'VB'), ('batteries', 'NNS'), ('is', 'VBZ'), ('just', 'RB'), ('a', 'DT'), ('gas', 'NN'), ('station', 'NN'), ('--', ':'), ('there', 'EX'), ('is', 'VBZ'), ('no', 'DT'), ('way', 'NN'), ('that', 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('going', 'VBG'), ('to', 'TO'), ('find', 'VB'), ('lithium', 'JJ'), ('batteries', 'NNS'), ('there', 'RB'), ('.', '.'), ("''", "''")]
#
# 20 - battery[-2]##not only is it inconvenient, but also the battery life span is short.
# [('battery', 'NN'), ('[', 'NN'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('not', 'RB'), ('only', 'RB'), ('is', 'VBZ'), ('it', 'PRP'), ('inconvenient', 'JJ'), (',', ','), ('but', 'CC'), ('also', 'RB'), ('the', 'DT'), ('battery', 'NN'), ('life', 'NN'), ('span', 'NN'), ('is', 'VBZ'), ('short', 'JJ'), ('.', '.')]
#
# 21 - ##the longest i've had it work was about 1 hour and 45 minutes.
# [('#', '#'), ('#', '#'), ('the', 'DT'), ('longest', 'JJS'), ('i', 'NN'), ("'ve", 'VBP'), ('had', 'VBD'), ('it', 'PRP'), ('work', 'NN'), ('was', 'VBD'), ('about', 'IN'), ('1', 'CD'), ('hour', 'NN'), ('and', 'CC'), ('45', 'CD'), ('minutes', 'NNS'), ('.', '.')]
#
# 22 - ##this isn't uncommon in cameras, though, just as long as you bring your charger and spare batteries, you should be fine.
# [('#', '#'), ('#', '#'), ('this', 'DT'), ('is', 'VBZ'), ("n't", 'RB'), ('uncommon', 'JJ'), ('in', 'IN'), ('cameras', 'NNS'), (',', ','), ('though', 'RB'), (',', ','), ('just', 'RB'), ('as', 'RB'), ('long', 'RB'), ('as', 'IN'), ('you', 'PRP'), ('bring', 'VBP'), ('your', 'PRP$'), ('charger', 'NN'), ('and', 'CC'), ('spare', 'JJ'), ('batteries', 'NNS'), (',', ','), ('you', 'PRP'), ('should', 'MD'), ('be', 'VB'), ('fine', 'JJ'), ('.', '.')]
#
# 23 - zoom[-2]##another problem i had with this camera was the zoom function.
# [('zoom', 'NN'), ('[', 'NNP'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('another', 'DT'), ('problem', 'NN'), ('i', 'NN'), ('had', 'VBD'), ('with', 'IN'), ('this', 'DT'), ('camera', 'NN'), ('was', 'VBD'), ('the', 'DT'), ('zoom', 'NN'), ('function', 'NN'), ('.', '.')]
#
# 24 - length[-2]##such a small zoom length that you would think that the zoom would be silent since it hardly zooms in...wrong!
# [('length', 'NN'), ('[', 'NNP'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('such', 'PDT'), ('a', 'DT'), ('small', 'JJ'), ('zoom', 'NN'), ('length', 'NN'), ('that', 'IN'), ('you', 'PRP'), ('would', 'MD'), ('think', 'VB'), ('that', 'IN'), ('the', 'DT'), ('zoom', 'NN'), ('would', 'MD'), ('be', 'VB'), ('silent', 'JJ'), ('since', 'IN'), ('it', 'PRP'), ('hardly', 'RB'), ('zooms', 'VBZ'), ('in', 'IN'), ('...', ':'), ('wrong', 'JJ'), ('!', '.')]
#
# 25 - ##very wrong.
# [('#', '#'), ('#', '#'), ('very', 'RB'), ('wrong', 'JJ'), ('.', '.')]
#
# 26 - zoom[-2]##the zoom function on this camera is so loud that sometimes you will be unable to use it if you find yourself in a situation where you must be quiet.
# [('zoom', 'NN'), ('[', 'NNP'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('zoom', 'NN'), ('function', 'NN'), ('on', 'IN'), ('this', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('so', 'RB'), ('loud', 'JJ'), ('that', 'IN'), ('sometimes', 'RB'), ('you', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('unable', 'JJ'), ('to', 'TO'), ('use', 'VB'), ('it', 'PRP'), ('if', 'IN'), ('you', 'PRP'), ('find', 'VBP'), ('yourself', 'PRP'), ('in', 'IN'), ('a', 'DT'), ('situation', 'NN'), ('where', 'WRB'), ('you', 'PRP'), ('must', 'MD'), ('be', 'VB'), ('quiet', 'JJ'), ('.', '.')]
#
# 27 - start-up[-2]##even just turning the camera on will move the lens a little, resulting in a noisy start-up.
# [('start-up', 'JJ'), ('[', 'NNP'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('even', 'RB'), ('just', 'RB'), ('turning', 'VBG'), ('the', 'DT'), ('camera', 'NN'), ('on', 'IN'), ('will', 'MD'), ('move', 'VB'), ('the', 'DT'), ('lens', 'FW'), ('a', 'DT'), ('little', 'JJ'), (',', ','), ('resulting', 'VBG'), ('in', 'IN'), ('a', 'DT'), ('noisy', 'JJ'), ('start-up', 'NN'), ('.', '.')]
#
# 28 - flash[-2]##the flash is very weak.
# [('flash', 'NN'), ('[', 'NN'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('flash', 'NN'), ('is', 'VBZ'), ('very', 'RB'), ('weak', 'JJ'), ('.', '.')]
#
# 29 - room[-2]##really dissapointing. if you are inside, you can't be any farther away then 10 feet in a lit room.
# [('room', 'NN'), ('[', 'NNP'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('really', 'RB'), ('dissapointing', 'VBG'), ('.', '.'), ('if', 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('inside', 'RB'), (',', ','), ('you', 'PRP'), ('ca', 'MD'), ("n't", 'RB'), ('be', 'VB'), ('any', 'DT'), ('farther', 'JJR'), ('away', 'RB'), ('then', 'RB'), ('10', 'CD'), ('feet', 'NNS'), ('in', 'IN'), ('a', 'DT'), ('lit', 'JJ'), ('room', 'NN'), ('.', '.')]
#
# 30 - macro[-2]##the last problem i found with this camera was the macro function.
# [('macro', 'NN'), ('[', 'NNP'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('last', 'JJ'), ('problem', 'NN'), ('i', 'NN'), ('found', 'VBD'), ('with', 'IN'), ('this', 'DT'), ('camera', 'NN'), ('was', 'VBD'), ('the', 'DT'), ('macro', 'JJ'), ('function', 'NN'), ('.', '.')]
#
# 31 - focus[-2]##the auto-focus on the camera seems to have trouble focusing on the subject.
# [('focus', 'NN'), ('[', 'NNP'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('auto-focus', 'NN'), ('on', 'IN'), ('the', 'DT'), ('camera', 'NN'), ('seems', 'VBZ'), ('to', 'TO'), ('have', 'VB'), ('trouble', 'NN'), ('focusing', 'VBG'), ('on', 'IN'), ('the', 'DT'), ('subject', 'NN'), ('.', '.')]
#
# 32 - ##to make matters work, there is no manual override to overcome this problem.
# [('#', '#'), ('#', '#'), ('to', 'TO'), ('make', 'VB'), ('matters', 'NNS'), ('work', 'VB'), (',', ','), ('there', 'EX'), ('is', 'VBZ'), ('no', 'DT'), ('manual', 'JJ'), ('override', 'NN'), ('to', 'TO'), ('overcome', 'VB'), ('this', 'DT'), ('problem', 'NN'), ('.', '.')]
#
# 33 - focus[+2]##the focus is great, though, if you are not taking a macro shot.
# [('focus', 'NN'), ('[', 'NNP'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('focus', 'NN'), ('is', 'VBZ'), ('great', 'JJ'), (',', ','), ('though', 'RB'), (',', ','), ('if', 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('not', 'RB'), ('taking', 'VBG'), ('a', 'DT'), ('macro', 'NN'), ('shot', 'NN'), ('.', '.')]
#
# 34 - ##these are all the flaws i found in the camera,
# [('#', '#'), ('#', '#'), ('these', 'DT'), ('are', 'VBP'), ('all', 'PDT'), ('the', 'DT'), ('flaws', 'NNS'), ('i', 'VBP'), ('found', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('camera', 'NN'), (',', ',')]
#
# 35 - ##it's not my first choice in cameras,
# [('#', '#'), ('#', '#'), ('it', 'PRP'), ("'s", 'VBZ'), ('not', 'RB'), ('my', 'PRP$'), ('first', 'JJ'), ('choice', 'NN'), ('in', 'IN'), ('cameras', 'NNS'), (',', ',')]
#
# 36 - camera[+2]##i have come across many other beginner cameras that i prefer over this camera, but the thing you have to keep in mind about this camera is the size.
# [('camera', 'NN'), ('[', 'NN'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('i', 'NNS'), ('have', 'VBP'), ('come', 'VBN'), ('across', 'IN'), ('many', 'JJ'), ('other', 'JJ'), ('beginner', 'NN'), ('cameras', 'NNS'), ('that', 'IN'), ('i', 'NN'), ('prefer', 'VBP'), ('over', 'IN'), ('this', 'DT'), ('camera', 'NN'), (',', ','), ('but', 'CC'), ('the', 'DT'), ('thing', 'NN'), ('you', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('keep', 'VB'), ('in', 'IN'), ('mind', 'NN'), ('about', 'IN'), ('this', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('size', 'NN'), ('.', '.')]
#
# 37 - ##if you are just looking for something to keep with you at all times, then this is a great camera choice.
# [('#', '#'), ('#', '#'), ('if', 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('just', 'RB'), ('looking', 'VBG'), ('for', 'IN'), ('something', 'NN'), ('to', 'TO'), ('keep', 'VB'), ('with', 'IN'), ('you', 'PRP'), ('at', 'IN'), ('all', 'DT'), ('times', 'NNS'), (',', ','), ('then', 'RB'), ('this', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('great', 'JJ'), ('camera', 'NN'), ('choice', 'NN'), ('.', '.')]
#
# 38 - ##i researched digital cameras for a month before purchasing the s100...
# [('#', '#'), ('#', '#'), ('i', 'NN'), ('researched', 'VBD'), ('digital', 'JJ'), ('cameras', 'NNS'), ('for', 'IN'), ('a', 'DT'), ('month', 'NN'), ('before', 'IN'), ('purchasing', 'VBG'), ('the', 'DT'), ('s100', 'NN'), ('...', ':')]
#
# 39 - ##after considering my needs further and researching the marketplace, i decided on the s100.
# [('#', '#'), ('#', '#'), ('after', 'IN'), ('considering', 'VBG'), ('my', 'PRP$'), ('needs', 'NNS'), ('further', 'RBR'), ('and', 'CC'), ('researching', 'VBG'), ('the', 'DT'), ('marketplace', 'NN'), (',', ','), ('i', 'NN'), ('decided', 'VBD'), ('on', 'IN'), ('the', 'DT'), ('s100', 'NN'), ('.', '.')]
#
# 40 - ##i have had this little gem for four months now.
# [('#', '#'), ('#', '#'), ('i', 'NN'), ('have', 'VBP'), ('had', 'VBN'), ('this', 'DT'), ('little', 'JJ'), ('gem', 'NN'), ('for', 'IN'), ('four', 'CD'), ('months', 'NNS'), ('now', 'RB'), ('.', '.')]
#
# 41 - ##it has given me zero problems, and the more i use it, the better i become at taking advantage of its strengths.
# [('#', '#'), ('#', '#'), ('it', 'PRP'), ('has', 'VBZ'), ('given', 'VBN'), ('me', 'PRP'), ('zero', 'CD'), ('problems', 'NNS'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('more', 'JJR'), ('i', 'JJ'), ('use', 'NN'), ('it', 'PRP'), (',', ','), ('the', 'DT'), ('better', 'JJR'), ('i', 'NN'), ('become', 'VBP'), ('at', 'IN'), ('taking', 'VBG'), ('advantage', 'NN'), ('of', 'IN'), ('its', 'PRP$'), ('strengths', 'NNS'), ('.', '.')]
#
# 42 - ##i had a regular canon elph (aps), as well as a jvc digital camera.
# [('#', '#'), ('#', '#'), ('i', 'NN'), ('had', 'VBD'), ('a', 'DT'), ('regular', 'JJ'), ('canon', 'NN'), ('elph', 'NN'), ('(', '('), ('aps', 'NNS'), (')', ')'), (',', ','), ('as', 'RB'), ('well', 'RB'), ('as', 'IN'), ('a', 'DT'), ('jvc', 'NN'), ('digital', 'JJ'), ('camera', 'NN'), ('.', '.')]
#
# 43 - ##i was looking for a blend of the two and so i bought this camera.
# [('#', '#'), ('#', '#'), ('i', 'NN'), ('was', 'VBD'), ('looking', 'VBG'), ('for', 'IN'), ('a', 'DT'), ('blend', 'NN'), ('of', 'IN'), ('the', 'DT'), ('two', 'CD'), ('and', 'CC'), ('so', 'RB'), ('i', 'JJ'), ('bought', 'VBD'), ('this', 'DT'), ('camera', 'NN'), ('.', '.')]
#
# 44 - ##i'll share some observations that may differ a bit from what other reviewers have noted.
# [('#', '#'), ('#', '#'), ('i', 'NN'), ("'ll", 'MD'), ('share', 'NN'), ('some', 'DT'), ('observations', 'NNS'), ('that', 'WDT'), ('may', 'MD'), ('differ', 'VB'), ('a', 'DT'), ('bit', 'NN'), ('from', 'IN'), ('what', 'WP'), ('other', 'JJ'), ('reviewers', 'NNS'), ('have', 'VBP'), ('noted', 'VBN'), ('.', '.')]
#
# 45 - ##1) it is perhaps too small.
# [('#', '#'), ('#', '#'), ('1', 'CD'), (')', ')'), ('it', 'PRP'), ('is', 'VBZ'), ('perhaps', 'RB'), ('too', 'RB'), ('small', 'JJ'), ('.', '.')]
#
# 46 - button[-2]##i find it a bit difficult to manage the very tiny buttons and impossible to read the icons without my reading glasses on.
# [('button', 'NN'), ('[', 'NNP'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('i', 'JJ'), ('find', 'VBP'), ('it', 'PRP'), ('a', 'DT'), ('bit', 'NN'), ('difficult', 'JJ'), ('to', 'TO'), ('manage', 'VB'), ('the', 'DT'), ('very', 'RB'), ('tiny', 'JJ'), ('buttons', 'NNS'), ('and', 'CC'), ('impossible', 'JJ'), ('to', 'TO'), ('read', 'VB'), ('the', 'DT'), ('icons', 'NNS'), ('without', 'IN'), ('my', 'PRP$'), ('reading', 'NN'), ('glasses', 'NNS'), ('on', 'IN'), ('.', '.')]
#
# 47 - size[-2]##its size makes holding it steady for long a bit of a challenge (not enough camera body to grip with more than your finger tips).
# [('size', 'NN'), ('[', 'NNP'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('its', 'PRP$'), ('size', 'NN'), ('makes', 'VBZ'), ('holding', 'VBG'), ('it', 'PRP'), ('steady', 'JJ'), ('for', 'IN'), ('long', 'RB'), ('a', 'DT'), ('bit', 'NN'), ('of', 'IN'), ('a', 'DT'), ('challenge', 'NN'), ('(', '('), ('not', 'RB'), ('enough', 'RB'), ('camera', 'NN'), ('body', 'NN'), ('to', 'TO'), ('grip', 'VB'), ('with', 'IN'), ('more', 'JJR'), ('than', 'IN'), ('your', 'PRP$'), ('finger', 'NN'), ('tips', 'NNS'), (')', ')'), ('.', '.')]
#
# 48 - picture[-2]##2) the delay from the time you fully depress the shutter to the time the picture is taken is too long and may yield some fuzzy shots.
# [('picture', 'NN'), ('[', 'VBZ'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('2', 'CD'), (')', ')'), ('the', 'DT'), ('delay', 'NN'), ('from', 'IN'), ('the', 'DT'), ('time', 'NN'), ('you', 'PRP'), ('fully', 'RB'), ('depress', 'VB'), ('the', 'DT'), ('shutter', 'NN'), ('to', 'TO'), ('the', 'DT'), ('time', 'NN'), ('the', 'DT'), ('picture', 'NN'), ('is', 'VBZ'), ('taken', 'VBN'), ('is', 'VBZ'), ('too', 'RB'), ('long', 'JJ'), ('and', 'CC'), ('may', 'MD'), ('yield', 'VB'), ('some', 'DT'), ('fuzzy', 'JJ'), ('shots', 'NNS'), ('.', '.')]
#
# 49 - autofocus[-2]##this is due to the unusually slow autofocus system.
# [('autofocus', 'NN'), ('[', 'NNP'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('this', 'DT'), ('is', 'VBZ'), ('due', 'JJ'), ('to', 'TO'), ('the', 'DT'), ('unusually', 'RB'), ('slow', 'JJ'), ('autofocus', 'NN'), ('system', 'NN'), ('.', '.')]
#
# 50 - ##3) the lack of an intermediate resolution setting, as other reviewers have suggested, is a problem, but that problem is meaningless with a larger compactflash memory card
# [('#', '#'), ('#', '#'), ('3', 'CD'), (')', ')'), ('the', 'DT'), ('lack', 'NN'), ('of', 'IN'), ('an', 'DT'), ('intermediate', 'JJ'), ('resolution', 'NN'), ('setting', 'NN'), (',', ','), ('as', 'IN'), ('other', 'JJ'), ('reviewers', 'NNS'), ('have', 'VBP'), ('suggested', 'VBN'), (',', ','), ('is', 'VBZ'), ('a', 'DT'), ('problem', 'NN'), (',', ','), ('but', 'CC'), ('that', 'DT'), ('problem', 'NN'), ('is', 'VBZ'), ('meaningless', 'JJ'), ('with', 'IN'), ('a', 'DT'), ('larger', 'JJR'), ('compactflash', 'JJ'), ('memory', 'NN'), ('card', 'NN')]
#
# 51 - ##(i got a 64 meg card for $... and it holds 105 pics at 1600 x 1200 res).
# [('#', '#'), ('#', '#'), ('(', '('), ('i', 'JJ'), ('got', 'VBD'), ('a', 'DT'), ('64', 'CD'), ('meg', 'NN'), ('card', 'NN'), ('for', 'IN'), ('$', '$'), ('...', ':'), ('and', 'CC'), ('it', 'PRP'), ('holds', 'VBZ'), ('105', 'CD'), ('pics', 'NNS'), ('at', 'IN'), ('1600', 'CD'), ('x', 'NN'), ('1200', 'CD'), ('res', 'NNS'), (')', ')'), ('.', '.')]
#
# 52 - camera[-2]##4) the camera gets really hot when you are busy snapping away.
# [('camera', 'NN'), ('[', 'NN'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('4', 'CD'), (')', ')'), ('the', 'DT'), ('camera', 'NN'), ('gets', 'VBZ'), ('really', 'RB'), ('hot', 'JJ'), ('when', 'WRB'), ('you', 'PRP'), ('are', 'VBP'), ('busy', 'JJ'), ('snapping', 'VBG'), ('away', 'RB'), ('.', '.')]
#
# 53 - ##it is hot enough to be annoying.
# [('#', '#'), ('#', '#'), ('it', 'PRP'), ('is', 'VBZ'), ('hot', 'JJ'), ('enough', 'RB'), ('to', 'TO'), ('be', 'VB'), ('annoying', 'VBG'), ('.', '.')]
#
# 54 - ##canon says it's normal.
# [('#', '#'), ('#', '#'), ('canon', 'NN'), ('says', 'VBZ'), ('it', 'PRP'), ("'s", 'VBZ'), ('normal', 'JJ'), ('.', '.')]
#
# 55 - ##i have found it gets less warm with the lcd off.
# [('#', '#'), ('#', '#'), ('i', 'NNS'), ('have', 'VBP'), ('found', 'VBN'), ('it', 'PRP'), ('gets', 'VBZ'), ('less', 'RBR'), ('warm', 'JJ'), ('with', 'IN'), ('the', 'DT'), ('lcd', 'NN'), ('off', 'RP'), ('.', '.')]
#
# 56 - picture[+3]##this wonderfully small digital camera produces fantastically good pictures printed on any decent photo-quality printer (with photo quality paper).
# [('picture', 'NN'), ('[', 'VBZ'), ('+3', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('this', 'DT'), ('wonderfully', 'RB'), ('small', 'JJ'), ('digital', 'JJ'), ('camera', 'NN'), ('produces', 'VBZ'), ('fantastically', 'RB'), ('good', 'JJ'), ('pictures', 'NNS'), ('printed', 'VBN'), ('on', 'IN'), ('any', 'DT'), ('decent', 'JJ'), ('photo-quality', 'NN'), ('printer', 'NN'), ('(', '('), ('with', 'IN'), ('photo', 'NN'), ('quality', 'NN'), ('paper', 'NN'), (')', ')'), ('.', '.')]
#
# 57 - ##it will not replace your high-end 35mm slr but it's a great toy to keep near you at all times for snapshots.
# [('#', '#'), ('#', '#'), ('it', 'PRP'), ('will', 'MD'), ('not', 'RB'), ('replace', 'VB'), ('your', 'PRP$'), ('high-end', 'JJ'), ('35mm', 'CD'), ('slr', 'NN'), ('but', 'CC'), ('it', 'PRP'), ("'s", 'VBZ'), ('a', 'DT'), ('great', 'JJ'), ('toy', 'NN'), ('to', 'TO'), ('keep', 'VB'), ('near', 'IN'), ('you', 'PRP'), ('at', 'IN'), ('all', 'DT'), ('times', 'NNS'), ('for', 'IN'), ('snapshots', 'NNS'), ('.', '.')]
#
# 58 - ##i have used many digital cameras.
# [('#', '#'), ('#', '#'), ('i', 'NN'), ('have', 'VBP'), ('used', 'VBN'), ('many', 'JJ'), ('digital', 'JJ'), ('cameras', 'NNS'), ('.', '.')]
#
# 59 - camera[+3]##this is the best camera you can have for digital images if you want to:
# [('camera', 'NN'), ('[', 'NN'), ('+3', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('this', 'DT'), ('is', 'VBZ'), ('the', 'DT'), ('best', 'JJS'), ('camera', 'NN'), ('you', 'PRP'), ('can', 'MD'), ('have', 'VB'), ('for', 'IN'), ('digital', 'JJ'), ('images', 'NNS'), ('if', 'IN'), ('you', 'PRP'), ('want', 'VBP'), ('to', 'TO'), (':', ':')]
#
# 60 - picture[+2],resolution[+2]##take quick pictures with excelent resolution
# [('picture', 'NN'), ('[', 'VBZ'), ('+2', 'NNP'), (']', 'NNP'), (',', ','), ('resolution', 'NN'), ('[', 'NNP'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('take', 'VB'), ('quick', 'JJ'), ('pictures', 'NNS'), ('with', 'IN'), ('excelent', 'JJ'), ('resolution', 'NN')]
#
# 61 - ##hate to wait between shots
# [('#', '#'), ('#', '#'), ('hate', 'NN'), ('to', 'TO'), ('wait', 'VB'), ('between', 'IN'), ('shots', 'NNS')]
#
# 62 - ##download it fast to your computer
# [('#', '#'), ('#', '#'), ('download', 'NN'), ('it', 'PRP'), ('fast', 'VBD'), ('to', 'TO'), ('your', 'PRP$'), ('computer', 'NN')]
#
# 63 - software[+2]##have a great and easy to use bundled software
# [('software', 'NN'), ('[', 'NNP'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('have', 'VBP'), ('a', 'DT'), ('great', 'JJ'), ('and', 'CC'), ('easy', 'JJ'), ('to', 'TO'), ('use', 'VB'), ('bundled', 'JJ'), ('software', 'NN')]
#
# 64 - ##travel with it without knowing you have it in your pocket
# [('#', '#'), ('#', '#'), ('travel', 'NN'), ('with', 'IN'), ('it', 'PRP'), ('without', 'IN'), ('knowing', 'VBG'), ('you', 'PRP'), ('have', 'VBP'), ('it', 'PRP'), ('in', 'IN'), ('your', 'PRP$'), ('pocket', 'NN')]
#
# 65 - battery[+1]##fyi, battery doesn't die if you don't use lcd
# [('battery', 'NN'), ('[', 'NN'), ('+1', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('fyi', 'NN'), (',', ','), ('battery', 'NN'), ('does', 'VBZ'), ("n't", 'RB'), ('die', 'VB'), ('if', 'IN'), ('you', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('use', 'VB'), ('lcd', 'NN')]
#
# 66 - camera[+2]##the color and light i captured with this camera on a 12-day trip to turkey (gorgeous vividly colored ceramic tiles inside darkened mosques) were far superior to anything i've ever gotten with a traditional 35-mm film camera.
# [('camera', 'NN'), ('[', 'NN'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('color', 'NN'), ('and', 'CC'), ('light', 'NN'), ('i', 'NNS'), ('captured', 'VBD'), ('with', 'IN'), ('this', 'DT'), ('camera', 'NN'), ('on', 'IN'), ('a', 'DT'), ('12-day', 'JJ'), ('trip', 'NN'), ('to', 'TO'), ('turkey', 'VB'), ('(', '('), ('gorgeous', 'JJ'), ('vividly', 'RB'), ('colored', 'VBD'), ('ceramic', 'JJ'), ('tiles', 'NNS'), ('inside', 'RB'), ('darkened', 'VBD'), ('mosques', 'NNS'), (')', ')'), ('were', 'VBD'), ('far', 'RB'), ('superior', 'JJ'), ('to', 'TO'), ('anything', 'NN'), ('i', 'JJ'), ("'ve", 'VBP'), ('ever', 'RB'), ('gotten', 'VBN'), ('with', 'IN'), ('a', 'DT'), ('traditional', 'JJ'), ('35-mm', 'JJ'), ('film', 'NN'), ('camera', 'NN'), ('.', '.')]
#
# 67 - ##i love this camera.
# [('#', '#'), ('#', '#'), ('i', 'JJ'), ('love', 'VBP'), ('this', 'DT'), ('camera', 'NN'), ('.', '.')]
#
# 68 - ##i don't believe this camera is still available. but if you can find one, you might like to get it.
# [('#', '#'), ('#', '#'), ('i', 'NNS'), ('do', 'VBP'), ("n't", 'RB'), ('believe', 'VB'), ('this', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('still', 'RB'), ('available', 'JJ'), ('.', '.'), ('but', 'CC'), ('if', 'IN'), ('you', 'PRP'), ('can', 'MD'), ('find', 'VB'), ('one', 'CD'), (',', ','), ('you', 'PRP'), ('might', 'MD'), ('like', 'VB'), ('to', 'TO'), ('get', 'VB'), ('it', 'PRP'), ('.', '.')]
#
# 69 - camera[+3]##it's still one of the smallest 2mp digital cameras on the market, and absolutely one of the best-built most stylish cameras ever.
# [('camera', 'NN'), ('[', 'NN'), ('+3', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('it', 'PRP'), ("'s", 'VBZ'), ('still', 'RB'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('smallest', 'JJS'), ('2mp', 'CD'), ('digital', 'JJ'), ('cameras', 'NNS'), ('on', 'IN'), ('the', 'DT'), ('market', 'NN'), (',', ','), ('and', 'CC'), ('absolutely', 'RB'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('best-built', 'JJ'), ('most', 'RBS'), ('stylish', 'JJ'), ('cameras', 'NNS'), ('ever', 'RB'), ('.', '.')]
#
# 70 - ##i bought my camera based on recommendations from my other friends who own it.
# [('#', '#'), ('#', '#'), ('i', 'NN'), ('bought', 'VBD'), ('my', 'PRP$'), ('camera', 'NN'), ('based', 'VBN'), ('on', 'IN'), ('recommendations', 'NNS'), ('from', 'IN'), ('my', 'PRP$'), ('other', 'JJ'), ('friends', 'NNS'), ('who', 'WP'), ('own', 'VBP'), ('it', 'PRP'), ('.', '.')]
#
# 71 - ##i am very pleased with my purchase.
# [('#', '#'), ('#', '#'), ('i', 'NN'), ('am', 'VBP'), ('very', 'RB'), ('pleased', 'JJ'), ('with', 'IN'), ('my', 'PRP$'), ('purchase', 'NN'), ('.', '.')]
#
# 72 - ##it's best to list the pros and cons of this camera:
# [('#', '#'), ('#', '#'), ('it', 'PRP'), ("'s", 'VBZ'), ('best', 'RBS'), ('to', 'TO'), ('list', 'VB'), ('the', 'DT'), ('pros', 'NNS'), ('and', 'CC'), ('cons', 'NNS'), ('of', 'IN'), ('this', 'DT'), ('camera', 'NN'), (':', ':')]
#
# 73 - ##i've been incredibly happy with this camera.
# [('#', '#'), ('#', '#'), ('i', 'JJ'), ("'ve", 'VBP'), ('been', 'VBN'), ('incredibly', 'RB'), ('happy', 'JJ'), ('with', 'IN'), ('this', 'DT'), ('camera', 'NN'), ('.', '.')]
#
# 74 - camera[+2]##this camera is great if you're used to a high-end slr.
# [('camera', 'NN'), ('[', 'NN'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('this', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('great', 'JJ'), ('if', 'IN'), ('you', 'PRP'), ("'re", 'VBP'), ('used', 'VBN'), ('to', 'TO'), ('a', 'DT'), ('high-end', 'JJ'), ('slr', 'NN'), ('.', '.')]
#
# 75 - ##it's overkill for simple snapshots, unless you've got way too much money to blow.
# [('#', '#'), ('#', '#'), ('it', 'PRP'), ("'s", 'VBZ'), ('overkill', 'NN'), ('for', 'IN'), ('simple', 'JJ'), ('snapshots', 'NNS'), (',', ','), ('unless', 'IN'), ('you', 'PRP'), ("'ve", 'VBP'), ('got', 'VBN'), ('way', 'NN'), ('too', 'RB'), ('much', 'JJ'), ('money', 'NN'), ('to', 'TO'), ('blow', 'VB'), ('.', '.')]
#
# 76 - exposure[+1]##exposure compensation in 1/3 stop increments (i leave it set on +1/3 stop to brighten up the default exposure, which goes a bit dark for my taste).
# [('exposure', 'NN'), ('[', 'VBZ'), ('+1', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('exposure', 'NN'), ('compensation', 'NN'), ('in', 'IN'), ('1/3', 'CD'), ('stop', 'JJ'), ('increments', 'NNS'), ('(', '('), ('i', 'NN'), ('leave', 'VBP'), ('it', 'PRP'), ('set', 'VBD'), ('on', 'IN'), ('+1/3', 'NNP'), ('stop', 'NN'), ('to', 'TO'), ('brighten', 'VB'), ('up', 'RP'), ('the', 'DT'), ('default', 'NN'), ('exposure', 'NN'), (',', ','), ('which', 'WDT'), ('goes', 'VBZ'), ('a', 'DT'), ('bit', 'NN'), ('dark', 'NN'), ('for', 'IN'), ('my', 'PRP$'), ('taste', 'NN'), (')', ')'), ('.', '.')]
#
# 77 - flash[+2]##slow-syncro flash, macro/infinity mode, etc.
# [('flash', 'NN'), ('[', 'NN'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('slow-syncro', 'JJ'), ('flash', 'NN'), (',', ','), ('macro/infinity', 'NN'), ('mode', 'NN'), (',', ','), ('etc', 'FW'), ('.', '.')]
#
# 78 - zoom[-1]##the zoom range is a little narrow (35-70mm in 35mm film equivalent), but given that the camera is the same as my wallet, i can't think of any real complaint.
# [('zoom', 'NN'), ('[', 'NNP'), ('-1', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('zoom', 'NN'), ('range', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('little', 'JJ'), ('narrow', 'JJ'), ('(', '('), ('35-70mm', 'JJ'), ('in', 'IN'), ('35mm', 'CD'), ('film', 'NN'), ('equivalent', 'NN'), (')', ')'), (',', ','), ('but', 'CC'), ('given', 'VBN'), ('that', 'IN'), ('the', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('same', 'JJ'), ('as', 'IN'), ('my', 'PRP$'), ('wallet', 'NN'), (',', ','), ('i', 'NN'), ('ca', 'MD'), ("n't", 'RB'), ('think', 'VB'), ('of', 'IN'), ('any', 'DT'), ('real', 'JJ'), ('complaint', 'NN'), ('.', '.')]
#
# 79 - body[+2],quality[+2]##the ss body is wonderful, feels high-quality.
# [('body', 'NN'), ('[', 'JJ'), ('+2', 'NNP'), (']', 'NNP'), (',', ','), ('quality', 'NN'), ('[', 'NNP'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('ss', 'NN'), ('body', 'NN'), ('is', 'VBZ'), ('wonderful', 'JJ'), (',', ','), ('feels', 'JJ'), ('high-quality', 'NN'), ('.', '.')]
#
# 80 - body[+2]##it's the same body as the popular elp2 aps camera (take a look at a standard credit card from your wallet and you'll have an idea of the front profile!).
# [('body', 'NN'), ('[', 'JJ'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('it', 'PRP'), ("'s", 'VBZ'), ('the', 'DT'), ('same', 'JJ'), ('body', 'NN'), ('as', 'IN'), ('the', 'DT'), ('popular', 'JJ'), ('elp2', 'NN'), ('aps', 'NNS'), ('camera', 'NN'), ('(', '('), ('take', 'VB'), ('a', 'DT'), ('look', 'NN'), ('at', 'IN'), ('a', 'DT'), ('standard', 'JJ'), ('credit', 'NN'), ('card', 'NN'), ('from', 'IN'), ('your', 'PRP$'), ('wallet', 'NN'), ('and', 'CC'), ('you', 'PRP'), ("'ll", 'MD'), ('have', 'VB'), ('an', 'DT'), ('idea', 'NN'), ('of', 'IN'), ('the', 'DT'), ('front', 'NN'), ('profile', 'NN'), ('!', '.'), (')', ')'), ('.', '.')]
#
# 81 - "##a 2x optical zoom (you can pretty much ignore any time a  manufacturer refers to ""digital zoom"")"
# [('``', '``'), ('#', '#'), ('#', '#'), ('a', 'DT'), ('2x', 'CD'), ('optical', 'JJ'), ('zoom', 'NN'), ('(', '('), ('you', 'PRP'), ('can', 'MD'), ('pretty', 'VB'), ('much', 'RB'), ('ignore', 'IN'), ('any', 'DT'), ('time', 'NN'), ('a', 'DT'), ('manufacturer', 'NN'), ('refers', 'NNS'), ('to', 'TO'), ('``', '``'), ("''", "''"), ('digital', 'JJ'), ('zoom', 'NN'), ("''", "''"), ("''", "''"), (')', ')'), ("''", "''")]
#
# 82 - ##i left the camera in my car in maine (not a very hot place) and the lcd screen cracked !
# [('#', '#'), ('#', '#'), ('i', 'NN'), ('left', 'VBD'), ('the', 'DT'), ('camera', 'NN'), ('in', 'IN'), ('my', 'PRP$'), ('car', 'NN'), ('in', 'IN'), ('maine', 'NN'), ('(', '('), ('not', 'RB'), ('a', 'DT'), ('very', 'RB'), ('hot', 'JJ'), ('place', 'NN'), (')', ')'), ('and', 'CC'), ('the', 'DT'), ('lcd', 'NN'), ('screen', 'NN'), ('cracked', 'VBD'), ('!', '.')]
#
# 83 - design[-2]##i then realized a major design flaw.
# [('design', 'NN'), ('[', 'NNP'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('i', 'NN'), ('then', 'RB'), ('realized', 'VBD'), ('a', 'DT'), ('major', 'JJ'), ('design', 'NN'), ('flaw', 'NN'), ('.', '.')]
#
# 84 - ##all the camera's functionality is only available (or selectable) when the screen is functional.
# [('#', '#'), ('#', '#'), ('all', 'PDT'), ('the', 'DT'), ('camera', 'NN'), ("'s", 'POS'), ('functionality', 'NN'), ('is', 'VBZ'), ('only', 'RB'), ('available', 'JJ'), ('(', '('), ('or', 'CC'), ('selectable', 'NN'), (')', ')'), ('when', 'WRB'), ('the', 'DT'), ('screen', 'NN'), ('is', 'VBZ'), ('functional', 'JJ'), ('.', '.')]
#
# 85 - ##when the screen stops working, you're out of luck !
# [('#', '#'), ('#', '#'), ('when', 'WRB'), ('the', 'DT'), ('screen', 'NN'), ('stops', 'VBZ'), ('working', 'VBG'), (',', ','), ('you', 'PRP'), ("'re", 'VBP'), ('out', 'IN'), ('of', 'IN'), ('luck', 'NN'), ('!', '.')]
#
# 86 - ##i wrote another review and this is the update.
# [('#', '#'), ('#', '#'), ('i', 'JJ'), ('wrote', 'VBD'), ('another', 'DT'), ('review', 'NN'), ('and', 'CC'), ('this', 'DT'), ('is', 'VBZ'), ('the', 'DT'), ('update', 'NN'), ('.', '.')]
#
# 87 - mode[+3],flash[+3],camera[+3]##i discovered that the camera has a manual mode that gives you total control over exposure, white balance, flash (red eye, person against bright background, flash on, flash off, flash automatic).
# [('mode', 'NN'), ('[', 'NNP'), ('+3', 'NNP'), (']', 'NNP'), (',', ','), ('flash', 'NN'), ('[', 'NNP'), ('+3', 'NNP'), (']', 'NNP'), (',', ','), ('camera', 'NN'), ('[', 'NN'), ('+3', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('i', 'NN'), ('discovered', 'VBD'), ('that', 'IN'), ('the', 'DT'), ('camera', 'NN'), ('has', 'VBZ'), ('a', 'DT'), ('manual', 'JJ'), ('mode', 'NN'), ('that', 'WDT'), ('gives', 'VBZ'), ('you', 'PRP'), ('total', 'JJ'), ('control', 'NN'), ('over', 'IN'), ('exposure', 'NN'), (',', ','), ('white', 'JJ'), ('balance', 'NN'), (',', ','), ('flash', 'NN'), ('(', '('), ('red', 'JJ'), ('eye', 'NN'), (',', ','), ('person', 'NN'), ('against', 'IN'), ('bright', 'JJ'), ('background', 'NN'), (',', ','), ('flash', 'NN'), ('on', 'IN'), (',', ','), ('flash', 'VB'), ('off', 'RP'), (',', ','), ('flash', 'JJ'), ('automatic', 'NN'), (')', ')'), ('.', '.')]
#
# 88 - ##i have used this camera for about 3 weeks so far, taking over 500 pictures.
# [('#', '#'), ('#', '#'), ('i', 'NN'), ('have', 'VBP'), ('used', 'VBN'), ('this', 'DT'), ('camera', 'NN'), ('for', 'IN'), ('about', 'RB'), ('3', 'CD'), ('weeks', 'NNS'), ('so', 'RB'), ('far', 'RB'), (',', ','), ('taking', 'VBG'), ('over', 'RP'), ('500', 'CD'), ('pictures', 'NNS'), ('.', '.')]
#
# 89 - ##i have 2 batteries and a 128 mb card.
# [('#', '#'), ('#', '#'), ('i', 'NNS'), ('have', 'VBP'), ('2', 'CD'), ('batteries', 'NNS'), ('and', 'CC'), ('a', 'DT'), ('128', 'CD'), ('mb', 'NN'), ('card', 'NN'), ('.', '.')]
#
# 90 - ##here are some useful facts:-
# [('#', '#'), ('#', '#'), ('here', 'RB'), ('are', 'VBP'), ('some', 'DT'), ('useful', 'JJ'), ('facts', 'NNS'), (':', ':'), ('-', ':')]
#
# 91 - picture[+2]##on a battery charge, the camera takes approximately 70 pictures, where the camera is opened and closed between pictures.
# [('picture', 'NN'), ('[', 'VBZ'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('on', 'IN'), ('a', 'DT'), ('battery', 'NN'), ('charge', 'NN'), (',', ','), ('the', 'DT'), ('camera', 'NN'), ('takes', 'VBZ'), ('approximately', 'RB'), ('70', 'CD'), ('pictures', 'NNS'), (',', ','), ('where', 'WRB'), ('the', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('opened', 'VBN'), ('and', 'CC'), ('closed', 'VBD'), ('between', 'IN'), ('pictures', 'NNS'), ('.', '.')]
#
# 92 - ##a 64mb card stores approximately 100 pictures at default resolution (ie between 500k and 1.5mb per picture).
# [('#', '#'), ('#', '#'), ('a', 'DT'), ('64mb', 'CD'), ('card', 'NN'), ('stores', 'NNS'), ('approximately', 'RB'), ('100', 'CD'), ('pictures', 'NNS'), ('at', 'IN'), ('default', 'NN'), ('resolution', 'NN'), ('(', '('), ('ie', 'NN'), ('between', 'IN'), ('500k', 'CD'), ('and', 'CC'), ('1.5mb', 'CD'), ('per', 'IN'), ('picture', 'NN'), (')', ')'), ('.', '.')]
#
# 93 - ##the viewfinder does not accurately represent the pucture being taken.
# [('#', '#'), ('#', '#'), ('the', 'DT'), ('viewfinder', 'NN'), ('does', 'VBZ'), ('not', 'RB'), ('accurately', 'RB'), ('represent', 'VBP'), ('the', 'DT'), ('pucture', 'NN'), ('being', 'VBG'), ('taken', 'VBN'), ('.', '.')]
#
# 94 - ##the lcd should be used.
# [('#', '#'), ('#', '#'), ('the', 'DT'), ('lcd', 'NN'), ('should', 'MD'), ('be', 'VB'), ('used', 'VBN'), ('.', '.')]
#
# 95 - ##however, in dark settings you must use the viewfinder.
# [('#', '#'), ('#', '#'), ('however', 'RB'), (',', ','), ('in', 'IN'), ('dark', 'JJ'), ('settings', 'NNS'), ('you', 'PRP'), ('must', 'MD'), ('use', 'VB'), ('the', 'DT'), ('viewfinder', 'NN'), ('.', '.')]
#
# 96 - zoom[-3]##the digital zoom is crap.
# [('zoom', 'NN'), ('[', 'NNP'), ('-3', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('digital', 'JJ'), ('zoom', 'NN'), ('is', 'VBZ'), ('crap', 'NN'), ('.', '.')]
#
# 97 - ##turn it off.
# [('#', '#'), ('#', '#'), ('turn', 'VB'), ('it', 'PRP'), ('off', 'RP'), ('.', '.')]
#
# 98 - ##it fits in your pocket.
# [('#', '#'), ('#', '#'), ('it', 'PRP'), ('fits', 'VBZ'), ('in', 'IN'), ('your', 'PRP$'), ('pocket', 'NN'), ('.', '.')]
#
# 99 - ##the closest competitor is the sony dsc-p1 (3.3mp).
# [('#', '#'), ('#', '#'), ('the', 'DT'), ('closest', 'JJS'), ('competitor', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('sony', 'JJ'), ('dsc-p1', 'NN'), ('(', '('), ('3.3mp', 'CD'), (')', ')'), ('.', '.')]
#
# 100 - camera[-2]##but that camera is a little larger and you defeat the whole purpose of having a truly portable camera.
# [('camera', 'NN'), ('[', 'NN'), ('-2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('but', 'CC'), ('that', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('little', 'JJ'), ('larger', 'JJR'), ('and', 'CC'), ('you', 'PRP'), ('defeat', 'VBP'), ('the', 'DT'), ('whole', 'JJ'), ('purpose', 'NN'), ('of', 'IN'), ('having', 'VBG'), ('a', 'DT'), ('truly', 'RB'), ('portable', 'JJ'), ('camera', 'NN'), ('.', '.')]
#
# 101 - ##i take my camera everywhere.
# [('#', '#'), ('#', '#'), ('i', 'NNS'), ('take', 'VBP'), ('my', 'PRP$'), ('camera', 'NN'), ('everywhere', 'RB'), ('.', '.')]
#
# 102 - ##tamrac makes a tiny pouch that is best for the camera.
# [('#', '#'), ('#', '#'), ('tamrac', 'NN'), ('makes', 'VBZ'), ('a', 'DT'), ('tiny', 'JJ'), ('pouch', 'NN'), ('that', 'WDT'), ('is', 'VBZ'), ('best', 'RBS'), ('for', 'IN'), ('the', 'DT'), ('camera', 'NN'), ('.', '.')]
#
# 103 - battery[+2]##the front even has a zipper for an extra battery and your wallet stuff.
# [('battery', 'NN'), ('[', 'NN'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('front', 'NN'), ('even', 'RB'), ('has', 'VBZ'), ('a', 'DT'), ('zipper', 'NN'), ('for', 'IN'), ('an', 'DT'), ('extra', 'JJ'), ('battery', 'NN'), ('and', 'CC'), ('your', 'PRP$'), ('wallet', 'NN'), ('stuff', 'NN'), ('.', '.')]
#
# 104 - panorama setting[+3]##the panorama setting is unbelieveable !
# [('panorama', 'NN'), ('setting', 'VBG'), ('[', 'NNP'), ('+3', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('panorama', 'NN'), ('setting', 'NN'), ('is', 'VBZ'), ('unbelieveable', 'JJ'), ('!', '.')]
#
# 105 - "memory[+2]##you take around 12 pictures in a circle, stitch them together and voila; you have a perfect memory of where you were standing ! "
# [('``', '``'), ('memory', 'NN'), ('[', 'JJ'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('you', 'PRP'), ('take', 'VBP'), ('around', 'RB'), ('12', 'CD'), ('pictures', 'NNS'), ('in', 'IN'), ('a', 'DT'), ('circle', 'NN'), (',', ','), ('stitch', 'VB'), ('them', 'PRP'), ('together', 'RB'), ('and', 'CC'), ('voila', 'RB'), (';', ':'), ('you', 'PRP'), ('have', 'VBP'), ('a', 'DT'), ('perfect', 'JJ'), ('memory', 'NN'), ('of', 'IN'), ('where', 'WRB'), ('you', 'PRP'), ('were', 'VBD'), ('standing', 'VBG'), ('!', '.'), ('``', '``')]
#
# 106 - picture[-1]##the pictures are a little dark sometimes.
# [('picture', 'NN'), ('[', 'VBZ'), ('-1', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('pictures', 'NNS'), ('are', 'VBP'), ('a', 'DT'), ('little', 'JJ'), ('dark', 'JJ'), ('sometimes', 'RB'), ('.', '.')]
#
# 107 - flash[+1]##you have the option to have the flash automatic or off.
# [('flash', 'NN'), ('[', 'NN'), ('+1', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('you', 'PRP'), ('have', 'VBP'), ('the', 'DT'), ('option', 'NN'), ('to', 'TO'), ('have', 'VB'), ('the', 'DT'), ('flash', 'JJ'), ('automatic', 'JJ'), ('or', 'CC'), ('off', 'RP'), ('.', '.')]
#
# 108 - ##the new canon s300 is 33% larger and 26% heavier than the s100.
# [('#', '#'), ('#', '#'), ('the', 'DT'), ('new', 'JJ'), ('canon', 'NN'), ('s300', 'NN'), ('is', 'VBZ'), ('33', 'CD'), ('%', 'NN'), ('larger', 'JJR'), ('and', 'CC'), ('26', 'CD'), ('%', 'NN'), ('heavier', 'JJR'), ('than', 'IN'), ('the', 'DT'), ('s100', 'NN'), ('.', '.')]
#
# 109 - mode[-1]##the movie mode can only record a max of 30 seconds at 160x120 per clip and a max of 4 seconds at 640x480.
# [('mode', 'NN'), ('[', 'NNP'), ('-1', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('movie', 'NN'), ('mode', 'NN'), ('can', 'MD'), ('only', 'RB'), ('record', 'VB'), ('a', 'DT'), ('max', 'NN'), ('of', 'IN'), ('30', 'CD'), ('seconds', 'NNS'), ('at', 'IN'), ('160x120', 'CD'), ('per', 'IN'), ('clip', 'NN'), ('and', 'CC'), ('a', 'DT'), ('max', 'NN'), ('of', 'IN'), ('4', 'CD'), ('seconds', 'NNS'), ('at', 'IN'), ('640x480', 'CD'), ('.', '.')]
#
# 110 - "mode[+2],resolution[+2]##it has one more resolution of 1024x768 and a ""normal"" compression mode.  and, it has the 3x zoom."
# ...
#
# 265 - ##i have a 35mm camera outfit that cost quite a bit of money a few years ago.
# [('#', '#'), ('#', '#'), ('i', 'NNS'), ('have', 'VBP'), ('a', 'DT'), ('35mm', 'CD'), ('camera', 'NN'), ('outfit', 'NN'), ('that', 'IN'), ('cost', 'NN'), ('quite', 'RB'), ('a', 'DT'), ('bit', 'NN'), ('of', 'IN'), ('money', 'NN'), ('a', 'DT'), ('few', 'JJ'), ('years', 'NNS'), ('ago', 'RB'), ('.', '.')]
#
# 266 - ##so, why the small digital elph, rather than one of the other cameras with better resolution or picture quality?
# [('#', '#'), ('#', '#'), ('so', 'RB'), (',', ','), ('why', 'WRB'), ('the', 'DT'), ('small', 'JJ'), ('digital', 'JJ'), ('elph', 'NN'), (',', ','), ('rather', 'RB'), ('than', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('other', 'JJ'), ('cameras', 'NNS'), ('with', 'IN'), ('better', 'JJR'), ('resolution', 'NN'), ('or', 'CC'), ('picture', 'NN'), ('quality', 'NN'), ('?', '.')]
#
# 267 - ##because, unless it's small, i won't cary it around.
# [('#', '#'), ('#', '#'), ('because', 'IN'), (',', ','), ('unless', 'IN'), ('it', 'PRP'), ("'s", 'VBZ'), ('small', 'JJ'), (',', ','), ('i', 'JJ'), ('wo', 'MD'), ("n't", 'RB'), ('cary', 'VB'), ('it', 'PRP'), ('around', 'RB'), ('.', '.')]
#
# 268 - ##if i won't cary it around, i won't use it, and if i won't use it, what's the point?
# [('#', '#'), ('#', '#'), ('if', 'IN'), ('i', 'NN'), ('wo', 'MD'), ("n't", 'RB'), ('cary', 'VB'), ('it', 'PRP'), ('around', 'IN'), (',', ','), ('i', 'NN'), ('wo', 'MD'), ("n't", 'RB'), ('use', 'VB'), ('it', 'PRP'), (',', ','), ('and', 'CC'), ('if', 'IN'), ('i', 'JJ'), ('wo', 'MD'), ("n't", 'RB'), ('use', 'VB'), ('it', 'PRP'), (',', ','), ('what', 'WP'), ("'s", 'VBZ'), ('the', 'DT'), ('point', 'NN'), ('?', '.')]
#
# 269 - battery[+1],memory[+1]##my first impression of elph s100 was that there couldn't possibly be room in the thing for anything other than a battery and a memory card.
# [('battery', 'NN'), ('[', 'NN'), ('+1', 'NNP'), (']', 'NNP'), (',', ','), ('memory', 'NN'), ('[', 'NNP'), ('+1', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('my', 'PRP$'), ('first', 'JJ'), ('impression', 'NN'), ('of', 'IN'), ('elph', 'JJ'), ('s100', 'NN'), ('was', 'VBD'), ('that', 'IN'), ('there', 'EX'), ('could', 'MD'), ("n't", 'RB'), ('possibly', 'RB'), ('be', 'VB'), ('room', 'NN'), ('in', 'IN'), ('the', 'DT'), ('thing', 'NN'), ('for', 'IN'), ('anything', 'NN'), ('other', 'JJ'), ('than', 'IN'), ('a', 'DT'), ('battery', 'NN'), ('and', 'CC'), ('a', 'DT'), ('memory', 'NN'), ('card', 'NN'), ('.', '.')]
#
# 270 - ##somehow, the engineers at canon did it, and the results are nothing less than astounding.
# [('#', '#'), ('#', '#'), ('somehow', 'RB'), (',', ','), ('the', 'DT'), ('engineers', 'NNS'), ('at', 'IN'), ('canon', 'NN'), ('did', 'VBD'), ('it', 'PRP'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('results', 'NNS'), ('are', 'VBP'), ('nothing', 'NN'), ('less', 'JJR'), ('than', 'IN'), ('astounding', 'VBG'), ('.', '.')]
#
# 271 - ##i was a little skeptical about what people had said about this camera, because it's just so small.
# [('#', '#'), ('#', '#'), ('i', 'NN'), ('was', 'VBD'), ('a', 'DT'), ('little', 'JJ'), ('skeptical', 'JJ'), ('about', 'IN'), ('what', 'WP'), ('people', 'NNS'), ('had', 'VBD'), ('said', 'VBD'), ('about', 'IN'), ('this', 'DT'), ('camera', 'NN'), (',', ','), ('because', 'IN'), ('it', 'PRP'), ("'s", 'VBZ'), ('just', 'RB'), ('so', 'RB'), ('small', 'JJ'), ('.', '.')]
#
# 272 - picture[+2],camera[+2]##after getting one for christmas from amazon, i'm now a believer:  the digital elph is truly the world's smallest digital camera that shoots great pictures.
# [('picture', 'NN'), ('[', 'VBZ'), ('+2', 'NNP'), (']', 'NNP'), (',', ','), ('camera', 'NN'), ('[', 'NN'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('after', 'IN'), ('getting', 'VBG'), ('one', 'CD'), ('for', 'IN'), ('christmas', 'NN'), ('from', 'IN'), ('amazon', 'NN'), (',', ','), ('i', 'JJ'), ("'m", 'VBP'), ('now', 'RB'), ('a', 'DT'), ('believer', 'NN'), (':', ':'), ('the', 'DT'), ('digital', 'JJ'), ('elph', 'NN'), ('is', 'VBZ'), ('truly', 'RB'), ('the', 'DT'), ('world', 'NN'), ("'s", 'POS'), ('smallest', 'JJS'), ('digital', 'JJ'), ('camera', 'NN'), ('that', 'WDT'), ('shoots', 'VBZ'), ('great', 'JJ'), ('pictures', 'NNS'), ('.', '.')]
#
# 273 - picture[+2]##i've had this camera just over 2 years and it takes pretty good pictures.
# [('picture', 'NN'), ('[', 'VBZ'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('i', 'JJ'), ("'ve", 'VBP'), ('had', 'VBN'), ('this', 'DT'), ('camera', 'NN'), ('just', 'RB'), ('over', 'IN'), ('2', 'CD'), ('years', 'NNS'), ('and', 'CC'), ('it', 'PRP'), ('takes', 'VBZ'), ('pretty', 'RB'), ('good', 'JJ'), ('pictures', 'NNS'), ('.', '.')]
#
# 274 - size[+3]##the size is tiny, which i love.
# [('size', 'NN'), ('[', 'NNP'), ('+3', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('size', 'NN'), ('is', 'VBZ'), ('tiny', 'JJ'), (',', ','), ('which', 'WDT'), ('i', 'VBP'), ('love', 'VBP'), ('.', '.')]
#
# 275 - ##we bought extra memory and a backup battery (so we can use one while the other is charging).
# [('#', '#'), ('#', '#'), ('we', 'PRP'), ('bought', 'VBD'), ('extra', 'JJ'), ('memory', 'NN'), ('and', 'CC'), ('a', 'DT'), ('backup', 'NN'), ('battery', 'NN'), ('(', '('), ('so', 'IN'), ('we', 'PRP'), ('can', 'MD'), ('use', 'VB'), ('one', 'CD'), ('while', 'IN'), ('the', 'DT'), ('other', 'JJ'), ('is', 'VBZ'), ('charging', 'VBG'), (')', ')'), ('.', '.')]
#
# 276 - "picture[-1]##sometimes the pictures are onthe dark side, but i'm able to fix that using the photoshop 6.0 ""adjust levels"" function ... not sure how a person would do that without photoshop, though."
# [('``', '``'), ('picture', 'NN'), ('[', 'JJ'), ('-1', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('sometimes', 'RB'), ('the', 'DT'), ('pictures', 'NNS'), ('are', 'VBP'), ('onthe', 'JJ'), ('dark', 'JJ'), ('side', 'NN'), (',', ','), ('but', 'CC'), ('i', 'JJ'), ("'m", 'VBP'), ('able', 'JJ'), ('to', 'TO'), ('fix', 'VB'), ('that', 'IN'), ('using', 'VBG'), ('the', 'DT'), ('photoshop', 'NN'), ('6.0', 'CD'), ('``', '``'), ("''", "''"), ('adjust', 'NN'), ('levels', 'NNS'), ("''", "''"), ("''", "''"), ('function', 'NN'), ('...', ':'), ('not', 'RB'), ('sure', 'JJ'), ('how', 'WRB'), ('a', 'DT'), ('person', 'NN'), ('would', 'MD'), ('do', 'VB'), ('that', 'DT'), ('without', 'IN'), ('photoshop', 'NN'), (',', ','), ('though', 'RB'), ('.', '.'), ("''", "''")]
#
# 277 - ##ok so i bookmarked pages about this camera on our home computer, in a place i was sure my wife would see, and loh and behold, what did i get.
# [('#', '#'), ('#', '#'), ('ok', 'IN'), ('so', 'RB'), ('i', 'JJ'), ('bookmarked', 'VBD'), ('pages', 'NNS'), ('about', 'IN'), ('this', 'DT'), ('camera', 'NN'), ('on', 'IN'), ('our', 'PRP$'), ('home', 'NN'), ('computer', 'NN'), (',', ','), ('in', 'IN'), ('a', 'DT'), ('place', 'NN'), ('i', 'NN'), ('was', 'VBD'), ('sure', 'JJ'), ('my', 'PRP$'), ('wife', 'NN'), ('would', 'MD'), ('see', 'VB'), (',', ','), ('and', 'CC'), ('loh', 'NN'), ('and', 'CC'), ('behold', 'NN'), (',', ','), ('what', 'WP'), ('did', 'VBD'), ('i', 'JJ'), ('get', 'NN'), ('.', '.')]
#
# 278 - ##thank you santa!
# [('#', '#'), ('#', '#'), ('thank', 'NN'), ('you', 'PRP'), ('santa', 'VBP'), ('!', '.')]
#
# 279 - ##i bought this camera at the end of august.
# [('#', '#'), ('#', '#'), ('i', 'JJ'), ('bought', 'VBD'), ('this', 'DT'), ('camera', 'NN'), ('at', 'IN'), ('the', 'DT'), ('end', 'NN'), ('of', 'IN'), ('august', 'NN'), ('.', '.')]
#
# 280 - ##with the camera i also bought a 128mb compact flash card, an extra battery, and a carrying case.
# [('#', '#'), ('#', '#'), ('with', 'IN'), ('the', 'DT'), ('camera', 'NN'), ('i', 'NN'), ('also', 'RB'), ('bought', 'VBD'), ('a', 'DT'), ('128mb', 'CD'), ('compact', 'JJ'), ('flash', 'JJ'), ('card', 'NN'), (',', ','), ('an', 'DT'), ('extra', 'JJ'), ('battery', 'NN'), (',', ','), ('and', 'CC'), ('a', 'DT'), ('carrying', 'VBG'), ('case', 'NN'), ('.', '.')]
# 281 - ##i also recently bought viking's intelliflash memory reader.
# [('#', '#'), ('#', '#'), ('i', 'NN'), ('also', 'RB'), ('recently', 'RB'), ('bought', 'VBD'), ('viking', 'VBG'), ("'s", 'POS'), ('intelliflash', 'JJ'), ('memory', 'NN'), ('reader', 'NN'), ('.', '.')]
#
# 282 - ##i've got a couple of digital cameras.
# [('#', '#'), ('#', '#'), ('i', 'JJ'), ("'ve", 'VBP'), ('got', 'VBN'), ('a', 'DT'), ('couple', 'NN'), ('of', 'IN'), ('digital', 'JJ'), ('cameras', 'NNS'), ('.', '.')]
#
# 283 - ##an olympus 2500 and an olympus 620.
# [('#', '#'), ('#', '#'), ('an', 'DT'), ('olympus', 'NN'), ('2500', 'CD'), ('and', 'CC'), ('an', 'DT'), ('olympus', 'JJ'), ('620', 'CD'), ('.', '.')]
#
# 284 - ##really like them,  they work well and the macro function of the 2500 really helps my ebay biz.
# [('#', '#'), ('#', '#'), ('really', 'RB'), ('like', 'IN'), ('them', 'PRP'), (',', ','), ('they', 'PRP'), ('work', 'VBP'), ('well', 'RB'), ('and', 'CC'), ('the', 'DT'), ('macro', 'JJ'), ('function', 'NN'), ('of', 'IN'), ('the', 'DT'), ('2500', 'CD'), ('really', 'RB'), ('helps', 'VB'), ('my', 'PRP$'), ('ebay', 'NN'), ('biz', 'NN'), ('.', '.')]
#
# 285 - camera[-1],case[-1]##but they are big cameras,  they have to reside in a large case,  they need all kinds of batteries,  in short they're a pain to lug around.
# [('camera', 'NN'), ('[', 'NN'), ('-1', 'NNP'), (']', 'NNP'), (',', ','), ('case', 'NN'), ('[', 'NNP'), ('-1', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('but', 'CC'), ('they', 'PRP'), ('are', 'VBP'), ('big', 'JJ'), ('cameras', 'NNS'), (',', ','), ('they', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('reside', 'VB'), ('in', 'IN'), ('a', 'DT'), ('large', 'JJ'), ('case', 'NN'), (',', ','), ('they', 'PRP'), ('need', 'VBP'), ('all', 'DT'), ('kinds', 'NNS'), ('of', 'IN'), ('batteries', 'NNS'), (',', ','), ('in', 'IN'), ('short', 'JJ'), ('they', 'PRP'), ("'re", 'VBP'), ('a', 'DT'), ('pain', 'NN'), ('to', 'TO'), ('lug', 'VB'), ('around', 'RP'), ('.', '.')]
#
# 286 - ##i've struggled for years with supposedly high-quality point and shoot 35mm cameras delivering astonishingly inconsistent results.
# [('#', '#'), ('#', '#'), ('i', 'JJ'), ("'ve", 'VBP'), ('struggled', 'VBN'), ('for', 'IN'), ('years', 'NNS'), ('with', 'IN'), ('supposedly', 'RB'), ('high-quality', 'JJ'), ('point', 'NN'), ('and', 'CC'), ('shoot', 'NN'), ('35mm', 'CD'), ('cameras', 'NNS'), ('delivering', 'VBG'), ('astonishingly', 'RB'), ('inconsistent', 'JJ'), ('results', 'NNS'), ('.', '.')]
#
# 287 - ##the canon s100 destroys this problem.
# [('#', '#'), ('#', '#'), ('the', 'DT'), ('canon', 'NN'), ('s100', 'NN'), ('destroys', 'VBZ'), ('this', 'DT'), ('problem', 'NN'), ('.', '.')]
#
# 288 - ##i've had this camera for roughly 3 weeks now and i've taken approximately 250 pictures.
# [('#', '#'), ('#', '#'), ('i', 'JJ'), ("'ve", 'VBP'), ('had', 'VBN'), ('this', 'DT'), ('camera', 'NN'), ('for', 'IN'), ('roughly', 'RB'), ('3', 'CD'), ('weeks', 'NNS'), ('now', 'RB'), ('and', 'CC'), ('i', 'VB'), ("'ve", 'VBP'), ('taken', 'VBN'), ('approximately', 'RB'), ('250', 'CD'), ('pictures', 'NNS'), ('.', '.')]
#
# 289 - ##the results are superb...  both in print and over the computer.
# [('#', '#'), ('#', '#'), ('the', 'DT'), ('results', 'NNS'), ('are', 'VBP'), ('superb', 'JJ'), ('...', ':'), ('both', 'DT'), ('in', 'IN'), ('print', 'NN'), ('and', 'CC'), ('over', 'IN'), ('the', 'DT'), ('computer', 'NN'), ('.', '.')]
#
# 290 - ##positives:
# [('#', '#'), ('#', '#'), ('positives', 'NNS'), (':', ':')]
#
# 291 - camera[+2]##this camera is so easy to use!
# [('camera', 'NN'), ('[', 'NN'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('this', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('so', 'RB'), ('easy', 'JJ'), ('to', 'TO'), ('use', 'VB'), ('!', '.')]
#
# 292 - ##i just took it out of the box, charged the battery, and started taking pictures.
# [('#', '#'), ('#', '#'), ('i', 'NN'), ('just', 'RB'), ('took', 'VBD'), ('it', 'PRP'), ('out', 'IN'), ('of', 'IN'), ('the', 'DT'), ('box', 'NN'), (',', ','), ('charged', 'VBD'), ('the', 'DT'), ('battery', 'NN'), (',', ','), ('and', 'CC'), ('started', 'VBD'), ('taking', 'VBG'), ('pictures', 'NNS'), ('.', '.')]
#
# 293 - ##all the features are incredibly intuitive, even for a novice like me.
# [('#', '#'), ('#', '#'), ('all', 'PDT'), ('the', 'DT'), ('features', 'NNS'), ('are', 'VBP'), ('incredibly', 'RB'), ('intuitive', 'JJ'), (',', ','), ('even', 'RB'), ('for', 'IN'), ('a', 'DT'), ('novice', 'NN'), ('like', 'IN'), ('me', 'PRP'), ('.', '.')]
#
# 294 - ##i would recommend getting a larger compact flash card, because once you start taking pictures, you won't want to stop.
# [('#', '#'), ('#', '#'), ('i', 'NN'), ('would', 'MD'), ('recommend', 'VB'), ('getting', 'VBG'), ('a', 'DT'), ('larger', 'JJR'), ('compact', 'JJ'), ('flash', 'NN'), ('card', 'NN'), (',', ','), ('because', 'IN'), ('once', 'RB'), ('you', 'PRP'), ('start', 'VBP'), ('taking', 'VBG'), ('pictures', 'NNS'), (',', ','), ('you', 'PRP'), ('wo', 'MD'), ("n't", 'RB'), ('want', 'VB'), ('to', 'TO'), ('stop', 'VB'), ('.', '.')]
#
# 295 - picture[+3],camera[+2]##the pictures are beautiful, and the camera is so small you can carry it anywhere.
# [('picture', 'NN'), ('[', 'VBZ'), ('+3', 'NNP'), (']', 'NNP'), (',', ','), ('camera', 'NN'), ('[', 'NN'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('the', 'DT'), ('pictures', 'NNS'), ('are', 'VBP'), ('beautiful', 'JJ'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('camera', 'NN'), ('is', 'VBZ'), ('so', 'RB'), ('small', 'JJ'), ('you', 'PRP'), ('can', 'MD'), ('carry', 'VB'), ('it', 'PRP'), ('anywhere', 'RB'), ('.', '.')]
#
# 296 - price[+2],feature[+2],size[+2]##i, as many others, have waited for many years for the convergence of price, features, size and ease of use to hit that happy center point.
# [('price', 'NN'), ('[', 'NNS'), ('+2', 'NNP'), (']', 'NNP'), (',', ','), ('feature', 'NN'), ('[', 'NNP'), ('+2', 'NNP'), (']', 'NNP'), (',', ','), ('size', 'NN'), ('[', 'NNP'), ('+2', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('i', 'NN'), (',', ','), ('as', 'IN'), ('many', 'JJ'), ('others', 'NNS'), (',', ','), ('have', 'VBP'), ('waited', 'VBN'), ('for', 'IN'), ('many', 'JJ'), ('years', 'NNS'), ('for', 'IN'), ('the', 'DT'), ('convergence', 'NN'), ('of', 'IN'), ('price', 'NN'), (',', ','), ('features', 'NNS'), (',', ','), ('size', 'NN'), ('and', 'CC'), ('ease', 'NN'), ('of', 'IN'), ('use', 'NN'), ('to', 'TO'), ('hit', 'VB'), ('that', 'DT'), ('happy', 'JJ'), ('center', 'NN'), ('point', 'NN'), ('.', '.')]
#
# 297 - ##well wait no more!
# [('#', '#'), ('#', '#'), ('well', 'RB'), ('wait', 'VBZ'), ('no', 'DT'), ('more', 'RBR'), ('!', '.')]
#
# 298 - ##i bought this little guy a few weeks back, and i have to saythat i never had so much fun with a new toy as this.
# [('#', '#'), ('#', '#'), ('i', 'JJ'), ('bought', 'VBD'), ('this', 'DT'), ('little', 'JJ'), ('guy', 'NN'), ('a', 'DT'), ('few', 'JJ'), ('weeks', 'NNS'), ('back', 'RB'), (',', ','), ('and', 'CC'), ('i', 'NNS'), ('have', 'VBP'), ('to', 'TO'), ('saythat', 'VB'), ('i', 'JJ'), ('never', 'RB'), ('had', 'VBD'), ('so', 'RB'), ('much', 'JJ'), ('fun', 'NN'), ('with', 'IN'), ('a', 'DT'), ('new', 'JJ'), ('toy', 'NN'), ('as', 'IN'), ('this', 'DT'), ('.', '.')]
#
# 299 - size[+3]##you willdefinitly appreciate the small size.
# [('size', 'NN'), ('[', 'NNP'), ('+3', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('you', 'PRP'), ('willdefinitly', 'RB'), ('appreciate', 'VBP'), ('the', 'DT'), ('small', 'JJ'), ('size', 'NN'), ('.', '.')]
#
# 300 - camera[+1]##you can take it anywhere withyou, unlike other bulky cameras, and capture every moment of yourlife.
# [('camera', 'NN'), ('[', 'NN'), ('+1', 'NNP'), (']', 'NNP'), ('#', '#'), ('#', '#'), ('you', 'PRP'), ('can', 'MD'), ('take', 'VB'), ('it', 'PRP'), ('anywhere', 'RB'), ('withyou', 'VBZ'), (',', ','), ('unlike', 'IN'), ('other', 'JJ'), ('bulky', 'NN'), ('cameras', 'NNS'), (',', ','), ('and', 'CC'), ('capture', 'NN'), ('every', 'DT'), ('moment', 'NN'), ('of', 'IN'), ('yourlife', 'NN'), ('.', '.')]
